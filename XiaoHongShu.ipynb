# %%
# coding=utf-8
import json
import random
import re
import urllib
import jieba
import jieba.analyse
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud
from itertools import izip
# %matplotlib inline
import seaborn as sns
import numpy as np
#SOMEHOW SOLVE THE MATPLOTLIB CHINESE DISPLAY ISSUE
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
def explore(url_key):
    url_key = urllib.quote(url_key)
    url = 'https://list.tmall.com/search_product.htm?spm=a220m.1000858.1000724.4.hjYCbX&brand=&q=' + url_key + '&sort=d&style=g&from=mallfp..pc_1_searchbutton&smAreaId=440100#J_Filter'
    print url
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.59 Safari/537.36','cookie':'_med=dw:1920&dh:1080&pw:1920&ph:1080&ist:0; hng=CN%7Czh-cn%7CCNY; uc3=nk2=&id2=&lg2=; uss=UoXmxfl6l1916VsxqitAJ3YkgcWAQzRNs9bUiOW%2FCYjl29dTiLTgZrIYsQ%3D%3D; tracknick=; t=14c82bf6d91f48927cf8795d1dde6036; cookie2=1cc6e1c1fbe36ae4a8960fa030e08a4c; _tb_token_=5FQGeE3r8lD6; tk_trace=1; _m_h5_tk=17da45b5aa92f58fac369f446d09271d_1489466339925; _m_h5_tk_enc=d1d6d3c80f55936585cb25ff4d2cb5d8; sm4=440100; cna=b2GPEF8u1CkCAbcDlG2w0Ddw; res=scroll%3A1515*2657-client%3A1515*760-offset%3A1515*2657-screen%3A1536*864; pnm_cku822=064UW5TcyMNYQwiAiwQRHhBfEF8QXtHcklnMWc%3D%7CUm5Ockt%2BSnNJcEV9RHBKcyU%3D%7CU2xMHDJ7G2AHYg8hAS8XLgAgDlIzVTleIFp0InQ%3D%7CVGhXd1llXGldZF5nUmpTZ11kU25Mc0h2T3BJd05xTndPcE5yTHZYDg%3D%3D%7CVWldfS0QMAkxESkJJ1gxSmYIJnAm%7CVmhIGCUFOBgkHCAYOAY7BD8fIxslHj4LMAkpFS0TKAg9AjlvOQ%3D%3D%7CV25Tbk5zU2xMcEl1VWtTaUlwJg%3D%3D; cq=ccp%3D1; l=AgcHbAXnwuavoS8WYWDLAThXF7HRDNvu; isg=Alxc6yyPaKinRhw7lSIg4qaoLXqcTwD_Yn28hzZdaMcqgfwLXuXQj9I5h16D'}
    response = requests.get(url,headers = headers).text
    soup = BeautifulSoup(response)
    #print soup
    # get SKU Link and ids
    total_content = str()
    sku_list = []
    
    # no. of SKUs
    
    for item in soup.select("p.productTitle a")[0:1]:
        href = item.get('href')
        href = 'https:' + href
        print href
        sku_response = requests.get(href).text
        sku_soup = BeautifulSoup(sku_response)
        sku_name = sku_soup.title.string
        sku_list.append(sku_name)
        print sku_name
        itemid_pattern = re.compile(r'detail\.tmall\.com/item\.htm\?id=(\d*)&skuId=')
        itemid = itemid_pattern.findall(href)
        sellerid_pattern = re.compile(r'&user_id=(\d*)&cat_id')
        sellerid = sellerid_pattern.findall(href)

        # no. of rate pages
        for i in range(1, 50):
            review_url = 'http://rate.tmall.com/list_detail_rate.htm?itemId=' + str(itemid[0]) + '&sellerId=' + str(
                sellerid[0]) + '&currentPage=' + str(i) + '&order=3'
            print review_url
            response = requests.get(review_url).text
            #response = response[15:] # erase the ratedetail heading to make it a standard json format
            #print response
            #response = json.loads(response)
            #reviews = [response['rateList'][i]['rateContent'] for i in range(1,20)]
            review_pattern = re.compile(r'\"rateContent\":\"(.*?)\",\"rateDate\":')
            reviews = review_pattern.findall(response)
            
            for review in reviews:
                 total_content += review
        
    tags = jieba.analyse.extract_tags(total_content, topK=100,  withWeight=1)
    words = [i[0] for i in tags]
    freq =  [i[1] for i in tags]
    #plt.rcdefaults()
    fig = plt.figure(figsize=(18,48))
    ax = fig.add_subplot(1,1,1)
    y_pos = np.arange(len(tags))
    ax.barh(y_pos, freq,  
            color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(words)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Frequency')
    title = u'High Frequency Words'
    ax.set_title(title)
    plt.show()
    
    # WC
    wordcloud = WordCloud(max_words=100).fit_words(tags)

    fig, ax1 = plt.subp lots(1, 1)
    fig.set_size_inches(12,6)
    #ax1.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3))
    ax1.imshow(wordcloud.recolor(random_state= 8))
    plt.axis("off")
    plt.show()

    
    return total_content,sku_list

# %%
def maskSelect(data, selectors):
    return (d for d, s in izip(data, selectors) if s)

# %%
def dive(key):
    content_list = re.split(u'，|。|！|？| ', total_content)
    mask = [key in i for i in content_list ]
    a = maskSelect(content_list,mask)
    sub_content= ''
    for i in a:
        print i
        sub_content  += i
    sub_tags = jieba.analyse.extract_tags(sub_content, topK=20, withWeight=1)
    for i in sub_tags:
        if i[0] == key:
            sub_tags.remove(i)
    sub_words = [i[0] for i in sub_tags]
    sub_freq =  [i[1] for i in sub_tags]
    plt.rcdefaults()
    fig, ax = plt.subplots()
    y_pos = np.arange(len(sub_tags))
    ax.barh(y_pos, sub_freq,  
            color='green', ecolor='black')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(sub_words)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Frequency')
    title = u'High Frequency Sub Words'
    ax.set_title(title)
    plt.show()

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.59 Safari/537.36','cookie':'_med=dw:1920&dh:1080&pw:1920&ph:1080&ist:0; hng=CN%7Czh-cn%7CCNY; uc3=nk2=&id2=&lg2=; uss=UoXmxfl6l1916VsxqitAJ3YkgcWAQzRNs9bUiOW%2FCYjl29dTiLTgZrIYsQ%3D%3D; tracknick=; t=14c82bf6d91f48927cf8795d1dde6036; cookie2=1cc6e1c1fbe36ae4a8960fa030e08a4c; _tb_token_=5FQGeE3r8lD6; tk_trace=1; _m_h5_tk=17da45b5aa92f58fac369f446d09271d_1489466339925; _m_h5_tk_enc=d1d6d3c80f55936585cb25ff4d2cb5d8; sm4=440100; cna=b2GPEF8u1CkCAbcDlG2w0Ddw; res=scroll%3A1515*2657-client%3A1515*760-offset%3A1515*2657-screen%3A1536*864; pnm_cku822=064UW5TcyMNYQwiAiwQRHhBfEF8QXtHcklnMWc%3D%7CUm5Ockt%2BSnNJcEV9RHBKcyU%3D%7CU2xMHDJ7G2AHYg8hAS8XLgAgDlIzVTleIFp0InQ%3D%7CVGhXd1llXGldZF5nUmpTZ11kU25Mc0h2T3BJd05xTndPcE5yTHZYDg%3D%3D%7CVWldfS0QMAkxESkJJ1gxSmYIJnAm%7CVmhIGCUFOBgkHCAYOAY7BD8fIxslHj4LMAkpFS0TKAg9AjlvOQ%3D%3D%7CV25Tbk5zU2xMcEl1VWtTaUlwJg%3D%3D; cq=ccp%3D1; l=AgcHbAXnwuavoS8WYWDLAThXF7HRDNvu; isg=Alxc6yyPaKinRhw7lSIg4qaoLXqcTwD_Yn28hzZdaMcqgfwLXuXQj9I5h16D'}

# %%
url_key = urllib.quote('micellar water')
url = 'http://www.xiaohongshu.com/discovery/item/56417ee922cfcd0e98dd66ce'
response = requests.get(url,headers = headers).text
soup = BeautifulSoup(response)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <!-- <html><head><title></title></head><body></body></html> -->
# <html class="pc">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃取精华300ml___化妆教程-小红书
#   </title>
#   <script>
#    var _XHS_ST = +"1491377995207"; window.ad_st = new Date().getTime() - _XHS_ST;
#   </script>
#   <meta content="澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃取精华300ml
# " name="description"/>
#   <meta content="no-transform " http-equiv="Cache-Control"/>
#   <meta content="3abbfaac4345ca4daaa5ad2282115298_1476771175" name="shenma-site-verification"/>
#   <meta content="swisse好不好,swisse怎么样" name="keywords"/>
#   <link href="//s.xiaohongshu.com" rel="dns-prefetch"/>
#   <link href="//img.xiaohongshu.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="//s.xiaohongshu.com" rel="preconnect"/>
#   <link crossorigin="" href="//img.xiaohongshu.com" rel="preconnect"/>
#   <meta content="mobile" name="application-device"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1.0,maximum-scale=1,user-scalable=no" name="viewport"/>
#   <meta content="telephone=no,address=no,email=no" name="format-detection"/>
#   <meta content="width" name="mobileOptimized"/>
#   <meta content="true" name="handheldFriendly"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <script src="//s.xiaohongshu.com/s/polyfill/*/polyfill-16c9a01.js">
#   </script>
#   <script>
#    G_time=+new Date;(function(w,e,a){w._fe=function(m,u,l){if(a)return;a=new Image().src='http://54.223.35.9:8081/fe-errors?e='+e(m)+'&t='+(+new Date)+'&u='+e(u||location.href)+'&l='+l};w.onerror=w._fe})(window,encodeURIComponent);(function(w,d,c,r){function s(){d.style.fontSize=50*(d.clientWidth/375)+'px'}s();w.addEventListener(c in w?c:r,s,!1)})(window,document.documentElement,'orientationchange','resize');_snq=[[]];_snq.o=function(t,v){_snq.push(['trackStructEvent','fad',t,0,0,0,{c:v.substr(0,200)}])}
#   </script>
#   <link href="//s.xiaohongshu.com/s/mobile-discovery/*/item-332a77e.css" rel="stylesheet"/>
#   <script main="" src="//s.xiaohongshu.com/s/neuron-14e8b91.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/combo/zepto/*/zepto-9196635.js,cookie/*/cookie-b6a4709.js,browser/*/browser-b4063de.js,ajax/*/ajax-fbd3d82.js,xhs-bridge/*/xhs-bridge-768b797.js,util/*/util-7e43b3e.js,events/*/events-c28a7ca.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/combo/align-to/*/align-to-1a64230.js,legacy-mask/*/legacy-mask-9d0669e.js,legacy-dialog/*/legacy-dialog-ef82dd5.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/combo/lazyload/*/lazyload-78ffb0b.js,xhs-tag/*/xhs-tag-434b59a.js,mobile-discovery/*/item-36ad155.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/xhs-weixin/*/xhs-weixin-e018c56.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/sticky/*/sticky-99f3172.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/item-list/*/item-list-77e1ee9.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/dropmenu/*/dropmenu-c2033da.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/note-list/*/note-list-b637a5b.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/mobile-download/*/download-dc2e4e5.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/m-navbar/*/navbar-d609fdb.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/tag-list/*/tag-list-65028b8.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/scroll-loader/*/scroll-loader-7a88db5.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/search-tag/*/search-tag-f737141.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/board-list/*/board-list-1af156a.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/xhs/*/xhs-75e4e4f.js">
#   </script>
#   <script async="" src="//s.xiaohongshu.com/s/droplist/*/droplist-b3bc327.js">
#   </script>
#  </head>
#  <body>
#   <span id="j_login_status" style="display:none;">
#    0
#   </span>
#   <nav class="navbar" id="navbar">
#    <a class="home" href="/">
#     <img alt="" class="logo" src="//s.xiaohongshu.com/s/mobile-navbar/*/lib/img/logo-be88e12.png"/>
#    </a>
#    <ul class="link-list">
#     <li>
#      <a href="/">
#       首页
#      </a>
#     </li>
#     <li>
#      <a href="/brand">
#       品牌
#      </a>
#     </li>
#     <li>
#      <a href="/category">
#       品类
#      </a>
#     </li>
#     <li>
#      <a href="/destinations">
#       地区
#      </a>
#     </li>
#    </ul>
#    <a class="search" href="/search/keyword">
#     <img alt="" class="search-icon" src="//s.xiaohongshu.com/s/m-navbar/*/lib/img/search-aa15f2d.png"/>
#    </a>
#   </nav>
#   <div class="mask">
#   </div>
#   <div class="searchContainer">
#    <div class="searchHeader">
#     <div class="searchBar">
#      <div class="inputContainer">
#       <svg class="icon" height="22" p-id="2020" style="position: absolute; top: 9.5px;" t="1487567019508" version="1.1" viewbox="0 0 1024 1024" width="22" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#        <path d="M787.2 748.8l-140.8-140.8C678.4 556.8 704 505.6 704 448c0-140.8-115.2-256-256-256S192 307.2 192 448s115.2 256 256 256c57.6 0 108.8-19.2 153.6-51.2l147.2 140.8c6.4 6.4 12.8 6.4 25.6 6.4 6.4 0 19.2 0 25.6-6.4C800 780.8 800 761.6 787.2 748.8zM256 448c0-102.4 83.2-192 192-192 102.4 0 192 83.2 192 192 0 102.4-83.2 192-192 192C339.2 640 256 550.4 256 448z" fill="#bfbfbf" p-id="2021">
#        </path>
#       </svg>
#       <input autofocus="autofocus" name="searchText" placeholder="搜索笔记、商品、品牌、地区" type="text"/>
#      </div>
#     </div>
#     <div class="cancelBtn">
#      取消
#     </div>
#    </div>
#    <div class="searchResult" id="searchResult">
#    </div>
#   </div>
#   <section class="note-container">
#    <div class="goods-images-list j_goods_image">
#     <div class="image-wrap j_image_list first">
#      <h3>
#       <img alt="澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃取精华300ml" class="image b_lazyload" data-index="0" data-src="https://o4.xiaohongshu.com/discovery/w640/52631302ac515136a7b8799c9ced3ed2_640_640_92.jpg" src=""/>
#      </h3>
#     </div>
#    </div>
#    <div class="user-info">
#     <div class="avatar" id="note_user_img">
#      <a alt="猫咪小酒窝" href="/user/profile/55e328c167bc654296b3fadb">
#       <img alt="猫咪小酒窝" src="https://img.xiaohongshu.com/avatar/55e328c167bc654296b3fadb.jpg@120w_120h_92q_1e_1c_1x.jpg"/>
#      </a>
#     </div>
#     <div class="user-name">
#      <a alt="猫咪小酒窝" href="/user/profile/55e328c167bc654296b3fadb">
#       猫咪小酒窝
#      </a>
#     </div>
#     <button class="follow j_show_download_dialog">
#      <img alt="关注猫咪小酒窝" src="//s.xiaohongshu.com/s/mobile-discovery/*/item/img/pink-cross-5619b31.png"/>
#      <span>
#       关注
#      </span>
#     </button>
#    </div>
#    <div class="note-desc">
#     <p class="content j_goods_desc">
#      澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃取精华300ml
#     </p>
#     <p class="content j_goods_desc">
#      创新微胶粒结构水(Micellar Water)，能於清洁肌肤的同时，维护肌肤脂质 ☆不含皂类，不起泡沫，不含香精及酒精成分适合所有肤质。一点都不会油腻，比较清爽自然。突破性的胶体水状(Micellar Water)科技，可同时卸除眼妆、底妆及进行洁颜三项功能！清爽的质地，给予肌肤畅快亲新的愉悦感受。孕妇，痘痘肌，敏感肌等任何肤质的都可以用哦，因为真的很天然！！！
#     </p>
#     <p class="content j_goods_desc">
#      【使用方法】
#     </p>
#     <p class="content j_goods_desc">
#      1.首先，我们要准备好工具：棉签、纸巾、化妆棉、卸妆水。
#     </p>
#     <p class="content j_goods_desc">
#      2. 我们先把纸巾对折好，压在睫毛的下方，用蘸了卸妆水的棉签从睫毛根部往下刷，注意要顺着睫毛的走向。
#     </p>
#     <p class="content j_goods_desc">
#      3.然后，用化妆棉蘸取适量的卸妆水，在眼妆部位轻抹，持续5秒左右。
#     </p>
#     <p class="content j_goods_desc">
#      4.再用蘸取了卸妆水的化妆棉将眼睛周围的妆抹去，要闭上双眼慢慢地从眼头向眼尾抹，抹下眼皮的时候注意要睁开眼睛向上望，以便能彻底的卸去下眼睑的妆。
#     </p>
#     <p class="content j_goods_desc">
#      5.卸完眼眉处的妆后基本上等于完成了大部分的卸妆工作，但我们也可以忽略细节部分。用准备好的棉签沾湿卸妆液，在眼睛部分将残留妆容仔细擦拭掉。
#     </p>
#     <p class="content j_goods_desc">
#      6.最后，再用化妆棉沾湿清水（温热的清水）再细细地擦拭一遍，然后用洁面乳洗一遍脸就大功告成了！
#     </p>
#    </div>
#    <div class="note-actions">
#     <time datetime="2015-11-10 13:21:45">
#      2015-11-10 13:21:45发布
#     </time>
#     <button class="collect-btn j_show_download_dialog">
#      <img alt=" 收藏该笔记" src="//s.xiaohongshu.com/s/mobile-discovery/*/item/img/star-a303dee.png"/>
#      <span>
#       收藏
#      </span>
#     </button>
#     <button class="like-btn j_show_download_dialog">
#      <img alt=" 点赞该笔记" src="//s.xiaohongshu.com/s/mobile-discovery/*/item/img/like-d0c2c39.png"/>
#      <span>
#       赞 · 6
#      </span>
#     </button>
#    </div>
#    <div class="comments">
#     <section class="comment-input-container">
#      <button class="comment-input j_show_download_dialog">
#       说点什么，让TA也认识看笔记的人吧
#      </button>
#     </section>
#    </div>
#   </section>
#   <section class="note-item-container">
#    <h3>
#     笔记内商品信息
#    </h3>
#    <div class="note-item" id="note_item">
#     <div class="item-cell">
#      <div class="item-title">
#       商品名称
#      </div>
#      <div class="item-content">
#       <h1>
#        澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃取精华300ml
#       </h1>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section class="recommend-goods">
#    <a class="recommend" href="/discovery/item/56417ee922cfcd0e98dd66ce/related_goods">
#     你可能会喜欢
#     <span>
#      更多商品
#      <img src="//s.xiaohongshu.com/s/mobile-discovery/*/item/img/arrow-right-da5cb9c.png"/>
#     </span>
#    </a>
#    <ul class="goods-list">
#     <li class="item">
#      <a href="/goods/57c977758340c30f88081035?xhs_g_s=0032">
#       <h3>
#        <img alt="聪明宝宝爱吃_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/d310afcaa133a3bf2784db57a316f7e3@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        聪明宝宝爱吃
#       </div>
#       <div class="price">
#        <em>
#         ¥ 88
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/5784a0a6a8e2913e91acf38a?xhs_g_s=0032">
#       <h3>
#        <img alt="给肌肤排排毒_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/221c3a9bd61daba8b368098f1a188388@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        给肌肤排排毒
#       </div>
#       <div class="price">
#        <em>
#         ¥ 236
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/577660a6a8e2912e228ca8d1?xhs_g_s=0032">
#       <h3>
#        <img alt="清洁护肤一套拿下_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/c3e5d493b09652974331490d09f8732f@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        清洁护肤一套拿下
#       </div>
#       <div class="price">
#        <em>
#         ¥ 599
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/57fcb510a8e291684b58c317?xhs_g_s=0032">
#       <h3>
#        <img alt="白嫩肌肤像抛过光_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/a13afa411b27cbe0ac30c3904d50ffd9@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        白嫩肌肤像抛过光
#       </div>
#       <div class="price">
#        <em>
#         ¥ 436
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/5804cd5a8340c34f859db875?xhs_g_s=0032">
#       <h3>
#        <img alt="乳头柔软哺乳不疼_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/3edf3732396cdf1d16784eb7d28d2a68@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        乳头柔软哺乳不疼
#       </div>
#       <div class="price">
#        <em>
#         ¥ 78
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/56d922e33431074b15e153b3?xhs_g_s=0032">
#       <h3>
#        <img alt="素颜也水润光泽_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/1b8ae9fb62ee9a83432e6e8653f2e13a@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        素颜也水润光泽
#       </div>
#       <div class="price">
#        <em>
#         ¥ 215
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/57fc85608340c323962238b2?xhs_g_s=0032">
#       <h3>
#        <img alt="顽固痘印都消失_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/094655b0c75421cc88ffa014f5443a62@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        顽固痘印都消失
#       </div>
#       <div class="price">
#        <em>
#         ¥ 1106
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/54ca4739b4c4d672dea1ff05?xhs_g_s=0032">
#       <h3>
#        <img alt="cosme榜单也有它_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/b9f6c785aad7c48a88b6a8db96fba0e5@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        cosme榜单也有它
#       </div>
#       <div class="price">
#        <em>
#         ¥ 38
#        </em>
#       </div>
#      </a>
#     </li>
#     <li class="item">
#      <a href="/goods/55ec3322d232e10d709f02d4?xhs_g_s=0032">
#       <h3>
#        <img alt="10秒钟水润满满_小红书_福利社" class="image lazyload" data-src="http://img.xiaohongshu.com/items/d47969e2753709a1d0a508fe734ffecc@_320w_320h_1e_1c_0i_90Q_1x_2o.jpg"/>
#       </h3>
#       <div class="name">
#        10秒钟水润满满
#       </div>
#       <div class="price">
#        <em>
#         ¥ 115
#        </em>
#       </div>
#      </a>
#     </li>
#    </ul>
#   </section>
#   <section class="related-discoveries-container padding-bottom">
#    <div class="related-discoveries">
#     相关笔记
#    </div>
#    <section class="note-list" id="note_list">
#     <ul class="left-branch">
#      <li class="note">
#       <a data-id="56f37c98d2c8a537d0e8d195" href="/discovery/item/56f37c98d2c8a537d0e8d195">
#        <h3>
#         <img alt="Swisse micellar小黄瓜萃取精华卸妆水_价格_怎么样_使用方法_对的_彩妆_化妆教程-小红书" class="image" src="http://o4.xiaohongshu.com/discovery/w1280/cc50e89f4456bf97053eda7c515b705c_1280_1280_92.jpg"/>
#        </h3>
#        <div class="desc">
#         对的，你没看错，SWISSE的牌子不单单只有大众的保健品，护肤品也很出名的。下图就是我最爱的这个卸妆
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/58c2bc5902f37d6fdbd105e4.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          罗佳
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/note-list/*/img/likes-icon-be12924.png"/>
#          </span>
#          203
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="55e64e7bd6e4a9430ad0ee20" href="/discovery/item/55e64e7bd6e4a9430ad0ee20">
#        <h3>
#         <img alt="澳洲Swisse MICELLAR Makeup Remover 卸妆液__卸妆-小红书" class="image" src="http://o4.xiaohongshu.com/discovery/w1280/8c5b57d0eb8c6b2259214ba1cf996e52_1280_1280_92.jpg"/>
#        </h3>
#        <div class="desc">
#         澳洲Swisse MICELLAR Makeup Remover 卸妆液～小黄瓜萃取精华300ml，
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/55c93dc967bc650cfff9df6d.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          澳洲_纽卡的一只羊
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/note-list/*/img/likes-icon-be12924.png"/>
#          </span>
#          11
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="561333ccf5a2634040d76656" href="/discovery/item/561333ccf5a2634040d76656">
#        <h3>
#         <img alt="之前一直都用BIODERMA的卸妆水_价格_怎么样_使用方法_SwisseMicellar卸妆水__悉尼买什么_化妆方法-小红书" class="image" src="https://o4.xiaohongshu.com/discovery/w640/88e6957c65dad86f562d4bf6ab518f84_640_640_92.jpg"/>
#        </h3>
#        <div class="desc">
#         之前一直都用BIODERMA的卸妆水，可是这次回国，我妈觉得好用就留给她了😥😥所以回悉尼只能用La
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="http://img.xiaohongshu.com/avatar/560af893f5a2637b16f0c55f.jpg@120w_120h_92q_1e_1c_1x.jpg"/>
#         <div class="name">
#          sunny_Kenji
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/note-list/*/img/likes-icon-be12924.png"/>
#          </span>
#          35
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="5632d2d2f5a2634530b6d4a6" href="/discovery/item/5632d2d2f5a2634530b6d4a6">
#        <h3>
#         <img alt="Swisse小黄瓜卸妆水_价格_怎么样_Swisse Micellar Makeup Remover_-小红书" class="image" src="http://o4.xiaohongshu.com/discovery/w640/75d8cbbbec8ad1c49869449623a60fe5_640_640_92.jpg"/>
#        </h3>
#        <div class="desc">
#         Swisse Micellar Makeup Remover，小黄瓜卸妆水，好用程度不输给植村秀哦
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/55fa2ef8d6e4a9550d8c9a92.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          🍉MiuMiu
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/note-list/*/img/likes-icon-be12924.png"/>
#          </span>
#          8
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="5841c9db046fc543a561ed78" href="/discovery/item/5841c9db046fc543a561ed78">
#        <h3>
#         <img alt="Swisse黄瓜卸妆水_价格_怎么样_澳洲swiss小黄瓜卸妆液_敏感肌干净护肤_澳大利亚买什么-小红书" class="image" src="http://ci.xiaohongshu.com/a827e5de-7512-4485-bb9c-0da009b9f073@r_1280w_1280h.jpg"/>
#        </h3>
#        <div class="title">
#         澳洲swiss小黄瓜卸妆液
#        </div>
#        <div class="desc">
#         来自澳洲 Swisse温泉水萃取小黄瓜卸妆液300ML
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/583300cb82ec3948679a9430.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          JING___
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/note-list/*/img/likes-icon-be12924.png"/>
#          </span>
#          2
#         </div>
#        </div>
#       </a>
#      </li>
#     </ul>
#     <ul class="right-branch">
#      <li class="note">
#       <a data-id="56faa173d1d3b928631f5952" href="/discovery/item/56faa173d1d3b928631f5952">
#        <h3>
#         <img alt="🎀🎀🎀swisse温泉水萃取小黄瓜 卸妆液_价格_怎么样_怎么用_Swisse小黄瓜卸妆水_卸得很干净__澳大利亚购物攻略_化妆方法-小红书" class="image" src="http://o4.xiaohongshu.com/discovery/w640/0676a347df50a96e3457f86481cb4212_640_640_92.jpg"/>
#        </h3>
#        <div class="desc">
#         🎀🎀🎀swisse温泉水萃取小黄瓜 卸妆液
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/563240a3f5a2630c4a4d9d04.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          Shelia
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/mobile-discovery/*/search/img/likes-icon-be12924.png"/>
#          </span>
#          259
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="57161aa8d1d3b9458149a384" href="/discovery/item/57161aa8d1d3b9458149a384">
#        <h3>
#         <img alt="Swisse小黄瓜卸妆水_价格_怎么样_使用方法_很温和__淡妆化妆步骤-小红书" class="image" src="http://ci.xiaohongshu.com/7a57d7a2-fad0-4972-9cb4-13c52a4ba826@r_1280w_1280h.jpg"/>
#        </h3>
#        <div class="desc">
#         很温和，不刺激，日常淡妆用四张卸妆棉就OK，眼妆最好用专门哒喽！
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/5693311802f37d289fa92d71.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          倾君之恋
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/mobile-discovery/*/search/img/likes-icon-be12924.png"/>
#          </span>
#          2
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="589d909dd1d3b96eed0c95c7" href="/discovery/item/589d909dd1d3b96eed0c95c7">
#        <h3>
#         <img alt="【swisse温泉小黄瓜卸妆水】温和到可以当爽肤水的卸妆水_卸妆油卸妆液保湿_淡妆化妆步骤-小红书" class="image" src="http://ci.xiaohongshu.com/ad105c0f-d23f-4134-be10-b0fe24c0bda4@r_1280w_1280h.jpg"/>
#        </h3>
#        <div class="title">
#         【swisse温泉小黄瓜卸妆水】温和到可以当爽肤水的卸妆水
#        </div>
#        <div class="desc">
#         【宝贝名称】swisse温泉水小黄瓜卸妆水
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/589d8a9d02f37d31c2051024.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          我是小红薯吖
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/mobile-discovery/*/search/img/likes-icon-be12924.png"/>
#          </span>
#          2
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="57a84085b46c5d6e4fca7c51" href="/discovery/item/57a84085b46c5d6e4fca7c51">
#        <h3>
#         <img alt="澳洲Swisse小黄瓜卸妆水温泉萃取孕妇敏感肌脸部清洁液_-小红书" class="image" src="http://ci.xiaohongshu.com/84a2fadc-25d6-4ae6-b6b4-906f238ae5c4@r_1280w_1280h.jpg"/>
#        </h3>
#        <div class="title">
#         澳洲Swisse小黄瓜卸妆水温泉萃取孕妇敏感肌脸部清洁液
#        </div>
#        <div class="desc">
#         【产品特点】
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="https://img.xiaohongshu.com/avatar/56586b3c0cdc2b223889dba2.jpg@80w_80h_90q_1e_1c_1x.jpg"/>
#         <div class="name">
#          糊涂妹_蓉
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/mobile-discovery/*/search/img/likes-icon-be12924.png"/>
#          </span>
#          赞
#         </div>
#        </div>
#       </a>
#      </li>
#      <li class="note">
#       <a data-id="57216c74d2c8a5482cf92859" href="/discovery/item/57216c74d2c8a5482cf92859">
#        <h3>
#         <img alt="😘Swisse小黄瓜卸妆水300ML_价格_怎么样_SwisseSwisse小黄瓜卸妆水_敏感肌毛孔孕妇_澳大利亚购物攻略-小红书" class="image" src="http://ci.xiaohongshu.com/5a51bc92-7d22-4440-b835-656d48af4706@r_1280w_1280h.jpg"/>
#        </h3>
#        <div class="desc">
#         😘Swisse小黄瓜卸妆水300ML
#        </div>
#        <div class="author">
#         <img alt="小红书" class="avatar" src="http://img.xiaohongshu.com/avatar/5578e981b4c4d614b67e169a.jpg@120w_120h_92q_1e_1c_1x.jpg"/>
#         <div class="name">
#          南洛里尔
#         </div>
#         <div class="likes j_show_download_dialog">
#          <span class="icon">
#           <img src="//s.xiaohongshu.com/s/mobile-discovery/*/search/img/likes-icon-be12924.png"/>
#          </span>
#          86
#         </div>
#        </div>
#       </a>
#      </li>
#     </ul>
#    </section>
#    <a class="total-discoveries" href="/discovery/item/56417ee922cfcd0e98dd66ce/related_discoveries">
#     所有相关笔记
#    </a>
#   </section>
#   <div class="ca-nary" id="mobile-discovery---item--css">
#   </div>
#   <script>
#    neuron.config({loaded:["cookie@*","droplist@*","align-to@*","tag-list@*","lazyload@*","util@*","scroll-loader@*","mobile-download@*/download.js","search-tag@*","dropmenu@*","sticky@*","legacy-mask@*","xhs-weixin@*","note-list@*","legacy-dialog@*","mobile-discovery@*/item.js","item-list@*","browser@*","xhs-bridge@*","xhs@*","zepto@*","ajax@*","board-list@*","xhs-tag@*","events@*","m-navbar@*/navbar.js"],path:'//s.xiaohongshu.com/s/',graph:{"0":["*",{"cookie@*":1,"note-list@*":2,"board-list@*":16,"xhs@*":4,"search-tag@*":6,"dropmenu@*":9,"zepto@*":3,"ajax@*":14,"legacy-dialog@*":12,"tag-list@*":17,"lazyload@*":18,"xhs-tag@*":19,"item-list@*":20,"scroll-loader@*":21,"browser@*":5,"xhs-weixin@*":22}],"1":["*"],"2":["*",{"zepto@*":3}],"3":["*"],"4":["*",{"browser@*":5}],"5":["*"],"6":["*",{"util@*":7,"events@*":8,"zepto@*":3}],"7":["*"],"8":["*",{"util@*":7}],"9":["*",{"util@*":7,"events@*":8,"droplist@*":10,"legacy-mask@*":11,"zepto@*":3}],"10":["*",{"util@*":7,"events@*":8,"zepto@*":3}],"11":["*",{"util@*":7,"events@*":8,"zepto@*":3}],"12":["*",{"util@*":7,"events@*":8,"align-to@*":13,"legacy-mask@*":11,"zepto@*":3}],"13":["*",{"zepto@*":3}],"14":["*",{"xhs-bridge@*":15,"zepto@*":3}],"15":["*",{"browser@*":5}],"16":["*",{"zepto@*":3}],"17":["*",{"events@*":8,"zepto@*":3}],"18":["*",{"util@*":7,"events@*":8,"zepto@*":3}],"19":["*",{"zepto@*":3}],"20":["*",{"zepto@*":3}],"21":["*",{"util@*":7,"events@*":8,"zepto@*":3}],"22":["*",{"zepto@*":3}],"23":["*",{"xhs-weixin@*":22,"browser@*":5,"xhs@*":4,"zepto@*":3,"legacy-dialog@*":12}],"24":["*",{"sticky@*":25,"zepto@*":3}],"25":["*",{"zepto@*":3}],"_":{"mobile-download@*":23,"m-navbar@*":24,"mobile-discovery@*":0}}});
#   </script>
#   <script>
#    facade('mobile-discovery/item.js', {"share_info":{"desc":"\u6fb3\u6d32Swisse MICELLAR Makeup Remover \u5378\u5986\u6db2\u5c0f\u9ec4\u74dc\u8403...","link":"http://www.xiaohongshu.com/discovery/item/56417ee922cfcd0e98dd66ce","imgUrl":"https://o4.xiaohongshu.com/discovery/w640/52631302ac515136a7b8799c9ced3ed2_640_640_92.jpg","title":""},"tags":[[]]});
# facade('mobile-download/download.js', {"deeplink_url":"xhsdiscover://1/item/56417ee922cfcd0e98dd66ce"});
# facade('m-navbar/navbar.js', {"sticky":true});
#   </script>
#   <div id="xhssharetitle" style="display:none">
#   </div>
#   <div id="xhssharecontent" style="display:none">
#    澳洲Swisse MICELLAR Makeup Remover 卸妆液小黄瓜萃...
#   </div>
#   <div id="xhssharelinkurl" style="display:none">
#    http://www.xiaohongshu.com/discovery/item/56417ee922cfcd0e98dd66ce
#   </div>
#   <div id="xhsshareimgurl" style="display:none">
#    http://o4.xiaohongshu.com/discovery/w640/52631302ac515136a7b8799c9ced3ed2_640_640_92.jpg
#   </div>
#   <script>
#    (function(a,w,c,d,l,o,b){try{function n(i){return a.childNodes[i]}function s(n,t){o(t,n[d]||n.innerHTML)}if(w!=top&&!/ngshu\.com/.test(top[l].host)){top[l].href=w[l].href;return}b=n(0);if(b[c]!=10){s(b,'ib');return}b=n(1);if(b[c]==8&&b[d].length!=56){s(b,'i');return}}catch(e){console.log(e)}})(document,this,'nodeType','nodeValue','location',_snq.o);(function(d,n,h){n=d.createElement('script');h=d.getElementsByTagName('head')[0];n.async=1;n.src="//s.xiaohongshu.com/s/snowplow/*/snowplow-82f7677.js";h.appendChild(n)})(document);(function(w,e,t,c,s,h){function o(x){return w.getComputedStyle ? w.getComputedStyle(x):x.currentStyle}function q(r){return Array.prototype.slice.call(document.querySelectorAll(r))};function u(m){new Image().src='http://54.223.35.9:8081/resources-load-fail?e='+e(m)+'&t='+(+new Date)+'l='+e(location.href)}var l=q(t);q(c).forEach(function(k){if(o(k)[s]!==h){var d=k.id.replace(/---/,'\/*\/').replace(/--/,'.');for(var i=0,g=l.length;i<g;i++){if(l[i].href.indexOf(d)>=0){u(l[i].href);break}}}});if(!neuron&&!zepto)u('js')}(window,encodeURIComponent,'link[rel=stylesheet]','.ca-nary','visibility','hidden'));(function(b,f,h,k,d){function l(a){c(b.childNodes||[],a);c(b.head.childNodes||[],a);c(b.documentElement.childNodes||[],a);c(b.body.childNodes||[],a)}function c(a,b){for(var c=0,d=a.length;c<d;c++)b(a[c])}function e(a){a.parentNode.removeChild(a)}function g(a){return!a||k.test(a)||!a.indexOf("xhsdiscover")||~a.indexOf("//localhost")||/^\/[^/]/.test(a)}setInterval(function(){c(b.querySelectorAll("link"),function(a){g(a.getAttribute&&a.getAttribute("href")||"")||(e(a),d("href",a))});c(b.querySelectorAll("a"),function(a){var b=a.getAttribute&&a.getAttribute("href")||"";b&&~b.indexOf("//")&&!g(b)&&!~a.className.indexOf("xhs-yo")&&(e(a),d("a",a))});c(b.querySelectorAll("img"),function(a){g(a.getAttribute&&a.getAttribute("src")||"")||a.className.indexOf('xhs-yo')>=0||(e(a),d("src",a))});c(b.querySelectorAll("iframe"),function(a){e(a);d("if",a)});l(function(a){var b=1===a.nodeType&&f(a);2147483643<(b?parseInt(b.zIndex)||0:0)&&!~a.className.indexOf("xhs-yo")&&(e(a),d("z",a))})},h)})(document,getComputedStyle,1E3,/\.xiaohongshu\.com/,function(b,f){_snq.o(b,f.outerHTML)})
#   </script>
#   <script>
#    var _hmt = _hmt || [];
# (function() {
#   var rg = /^https?:\/\/(www|m)\.xiaohongshu\.com/gi
#   var l = window.location.href
#
#   if(!rg.test(l)) {
#     return
#   }
#   var hm = document.createElement("script");
#   hm.src = "//hm.baidu.com/hm.js?d0ae755ac51e3c5ff9b1596b0c09c826";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   var bp = document.createElement('script');
#   var curProtocol = window.location.protocol.split(':')[0];
#   if (curProtocol === 'https') {
#     bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else {
#     bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(bp, s);
# })();
#   </script>
#  </body>
# </html>
